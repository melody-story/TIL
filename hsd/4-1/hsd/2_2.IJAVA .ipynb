# %% [markdown]
# <div class="alert alert-block" style="border: 1px solid #1E90FF;background-color:#BECDDD;font-size:1.2em;line-height:1.4em">
# - 강의자료를 무단으로 전재, 방송, 복사, 배포, 전시, 판매, 왜곡, 변조, 개작하는 것은 금지되어 있습니다.<br>
# </div>

# %% [markdown]
# #### 1. IJAVA 설치
#
# <div class="alert alert-block" style="border: 1px solid #9900FF;background-color:#99CCCC;padding:10px">
# <font size="3em" style="font-weight:bold;color:#990099;"> Java JDK 가 버전 9 이상 설치되어 있어야 하며, 이전 JDK 설치 영상으로 설치 후 진행 해야 함 </font>
# </div>
#
#  - IJava: https://github.com/SpencerPark/IJava/releases
#  - 링크를 통해서 Release Tab의 Asset에서 ijava-최신버전.zip 다운로드
#  - 압축을 풀고 파일들을 주피터 노트북 파일이 있는 폴더에 복사함
#
# <br><br>
#
# - 설치 방법
# > 주피터 노트북에서 터미널 명령을 실행하면, 폴더 경로만 맞춰주시면 바로 실행이 됩니다
#
#      ```bash
#      !python install.py --sys-prefix
#      ```
#
# > 설치 완료 후, 컴퓨터를 리부팅 또는 주피터 노트북을 다시 실행함

# %%
# !python install.py --sys-prefix
# Out:
# Installed java kernel into "c:\Users\melody\MelodyGit\TIL\.venv\share\jupyter\kernels\java"
# c:\Users\melody\MelodyGit\TIL\hsd\4-1\hsd\install.py:164: DeprecationWarning: replace is ignored. Installing a kernelspec always replaces an existing installation
#   install_dest = KernelSpecManager().install_kernel_spec(
